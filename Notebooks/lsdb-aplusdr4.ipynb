# %%
import lsdb
import splusdata
import pandas as pd
from getpass import getpass

# %%
# This will print all available links

print(splusdata.get_hipscats())
# Out:
# {'dr4_vacs': {'qso_z': {'hipscats': ['qso_z'], 'margins': ['qso_z_2arcsec']}, 'photozs': {'hipscats': ['photozs'], 'margins': ['photozs_2arcsec']}, 'calib_flag': {'hipscats': ['calib_flag'], 'margins': ['calib_flag_2arcsec']}, 'sqg': {'hipscats': ['sqg'], 'margins': ['sqg_2arcsec']}}, 'sdr1': {'hipscats': ['shorts'], 'margins': ['shorts_2arcsec']}, 'dr4': {'hipscats': ['single', 'dual', 'psf'], 'margins': ['psf_2arcsec', 'single_2arcsec', 'dual_2arcsec']}}

# %%
# This will search for a specific pattern
print(splusdata.get_hipscats("dr4/dual"))
# Out:
# [['https://splus.cloud/HIPS/catalogs/dr4/dual/', 'https://splus.cloud/HIPS/catalogs/dr4/dual_2arcsec/']]

# %%
from dask.distributed import Client
client = Client(n_workers=10, memory_limit="8GB")
print(client)
# Out:
# <Client: 'tcp://127.0.0.1:38533' processes=10 threads=20, memory=74.51 GiB>

# %%
dr4_links = splusdata.get_hipscats("idr4/dual")[0]
dr4_links
# Out:
# ['https://splus.cloud/HIPS/catalogs/dr4/dual/',
#  'https://splus.cloud/HIPS/catalogs/dr4/dual_2arcsec/']

# %%
dr4_margin = lsdb.read_hipscat(dr4_links[1])
for i in dr4_margin.columns:
    print(i)
# Out:
# ID
# RA
# DEC
# A
# B
# BACKGROUND
# BACKGROUND_J0378
# BACKGROUND_J0395
# BACKGROUND_J0410
# BACKGROUND_J0430
# BACKGROUND_J0515
# BACKGROUND_J0660
# BACKGROUND_J0861
# BACKGROUND_g
# BACKGROUND_i
# BACKGROUND_r
# BACKGROUND_u
# BACKGROUND_z
# CLASS_STAR
# DET_ID_dual
# EBV_SCH
# ELLIPTICITY
# ELONGATION
# FLUX_RADIUS_20
# FLUX_RADIUS_50
# FLUX_RADIUS_70
# FLUX_RADIUS_90
# FWHM
# FWHM_J0378
# FWHM_J0395
# FWHM_J0410
# FWHM_J0430
# FWHM_J0515
# FWHM_J0660
# FWHM_J0861
# FWHM_g
# FWHM_i
# FWHM_n
# FWHM_n_J0378
# FWHM_n_J0395
# FWHM_n_J0410
# FWHM_n_J0430
# FWHM_n_J0515
# FWHM_n_J0660
# FWHM_n_J0861
# FWHM_n_g
# FWHM_n_i
# FWHM_n_r
# FWHM_n_u
# FWHM_n_z
# FWHM_r
# FWHM_u
# FWHM_z
# Field
# ID_DEC
# ID_RA
# ISOarea
# J0378_ID_dual
# J0378_PStotal
# J0378_aper_3
# J0378_aper_6
# J0378_auto
# J0378_iso
# J0378_petro
# J0395_ID_dual
# J0395_PStotal
# J0395_aper_3
# J0395_aper_6
# J0395_auto
# J0395_iso
# J0395_petro
# J0410_ID_dual
# J0410_PStotal
# J0410_aper_3
# J0410_aper_6
# J0410_auto
# J0410_iso
# J0410_petro
# J0430_ID_dual
# J0430_PStotal
# J0430_aper_3
# J0430_aper_6
# J0430_auto
# J0430_iso
# J0430_petro
# J0515_ID_dual
# J0515_PStotal
# J0515_aper_3
# J0515_aper_6
# J0515_auto
# J0515_iso
# J0515_petro
# J0660_ID_dual
# J0660_PStotal
# J0660_aper_3
# J0660_aper_6
# J0660_auto
# J0660_iso
# J0660_petro
# J0861_ID_dual
# J0861_PStotal
# J0861_aper_3
# J0861_aper_6
# J0861_auto
# J0861_iso
# J0861_petro
# KRON_RADIUS
# MU_MAX_INST
# MU_MAX_J0378
# MU_MAX_J0395
# MU_MAX_J0410
# MU_MAX_J0430
# MU_MAX_J0515
# MU_MAX_J0660
# MU_MAX_J0861
# MU_MAX_g
# MU_MAX_i
# MU_MAX_r
# MU_MAX_u
# MU_MAX_z
# MU_THRESHOLD_INST
# MU_THRESHOLD_J0378
# MU_THRESHOLD_J0395
# MU_THRESHOLD_J0410
# MU_THRESHOLD_J0430
# MU_THRESHOLD_J0515
# MU_THRESHOLD_J0660
# MU_THRESHOLD_J0861
# MU_THRESHOLD_g
# MU_THRESHOLD_i
# MU_THRESHOLD_r
# MU_THRESHOLD_u
# MU_THRESHOLD_z
# PETRO_RADIUS
# PHOT_ID_DEC_dual
# PHOT_ID_RA_dual
# PHOT_ID_dual
# SEX_FLAGS_DET
# SEX_FLAGS_J0378
# SEX_FLAGS_J0395
# SEX_FLAGS_J0410
# SEX_FLAGS_J0430
# SEX_FLAGS_J0515
# SEX_FLAGS_J0660
# SEX_FLAGS_J0861
# SEX_FLAGS_g
# SEX_FLAGS_i
# SEX_FLAGS_r
# SEX_FLAGS_u
# SEX_FLAGS_z
# SEX_NUMBER_DET
# SEX_NUMBER_J0378
# SEX_NUMBER_J0395
# SEX_NUMBER_J0410
# SEX_NUMBER_J0430
# SEX_NUMBER_J0515
# SEX_NUMBER_J0660
# SEX_NUMBER_J0861
# SEX_NUMBER_g
# SEX_NUMBER_i
# SEX_NUMBER_r
# SEX_NUMBER_u
# SEX_NUMBER_z
# THETA
# THRESHOLD
# THRESHOLD_J0378
# THRESHOLD_J0395
# THRESHOLD_J0410
# THRESHOLD_J0430
# THRESHOLD_J0515
# THRESHOLD_J0660
# THRESHOLD_J0861
# THRESHOLD_g
# THRESHOLD_i
# THRESHOLD_r
# THRESHOLD_u
# THRESHOLD_z
# X
# Y
# calib_strat
# e_J0378_PStotal
# e_J0378_aper_3
# e_J0378_aper_6
# e_J0378_auto
# e_J0378_iso
# e_J0378_petro
# e_J0395_PStotal
# e_J0395_aper_3
# e_J0395_aper_6
# e_J0395_auto
# e_J0395_iso
# e_J0395_petro
# e_J0410_PStotal
# e_J0410_aper_3
# e_J0410_aper_6
# e_J0410_auto
# e_J0410_iso
# e_J0410_petro
# e_J0430_PStotal
# e_J0430_aper_3
# e_J0430_aper_6
# e_J0430_auto
# e_J0430_iso
# e_J0430_petro
# e_J0515_PStotal
# e_J0515_aper_3
# e_J0515_aper_6
# e_J0515_auto
# e_J0515_iso
# e_J0515_petro
# e_J0660_PStotal
# e_J0660_aper_3
# e_J0660_aper_6
# e_J0660_auto
# e_J0660_iso
# e_J0660_petro
# e_J0861_PStotal
# e_J0861_aper_3
# e_J0861_aper_6
# e_J0861_auto
# e_J0861_iso
# e_J0861_petro
# e_g_PStotal
# e_g_aper_3
# e_g_aper_6
# e_g_auto
# e_g_iso
# e_g_petro
# e_i_PStotal
# e_i_aper_3
# e_i_aper_6
# e_i_auto
# e_i_iso
# e_i_petro
# e_r_PStotal
# e_r_aper_3
# e_r_aper_6
# e_r_auto
# e_r_iso
# e_r_petro
# e_u_PStotal
# e_u_aper_3
# e_u_aper_6
# e_u_auto
# e_u_iso
# e_u_petro
# e_z_PStotal
# e_z_aper_3
# e_z_aper_6
# e_z_auto
# e_z_iso
# e_z_petro
# g_ID_dual
# g_PStotal
# g_aper_3
# g_aper_6
# g_auto
# g_iso
# g_petro
# i_ID_dual
# i_PStotal
# i_aper_3
# i_aper_6
# i_auto
# i_iso
# i_petro
# r_ID_dual
# r_PStotal
# r_aper_3
# r_aper_6
# r_auto
# r_iso
# r_petro
# s2n_DET_PStotal
# s2n_DET_aper_3
# s2n_DET_aper_6
# s2n_DET_auto
# s2n_DET_iso
# s2n_DET_petro
# s2n_J0378_PStotal
# s2n_J0378_aper_3
# s2n_J0378_aper_6
# s2n_J0378_auto
# s2n_J0378_iso
# s2n_J0378_petro
# s2n_J0395_PStotal
# s2n_J0395_aper_3
# s2n_J0395_aper_6
# s2n_J0395_auto
# s2n_J0395_iso
# s2n_J0395_petro
# s2n_J0410_PStotal
# s2n_J0410_aper_3
# s2n_J0410_aper_6
# s2n_J0410_auto
# s2n_J0410_iso
# s2n_J0410_petro
# s2n_J0430_PStotal
# s2n_J0430_aper_3
# s2n_J0430_aper_6
# s2n_J0430_auto
# s2n_J0430_iso
# s2n_J0430_petro
# s2n_J0515_PStotal
# s2n_J0515_aper_3
# s2n_J0515_aper_6
# s2n_J0515_auto
# s2n_J0515_iso
# s2n_J0515_petro
# s2n_J0660_PStotal
# s2n_J0660_aper_3
# s2n_J0660_aper_6
# s2n_J0660_auto
# s2n_J0660_iso
# s2n_J0660_petro
# s2n_J0861_PStotal
# s2n_J0861_aper_3
# s2n_J0861_aper_6
# s2n_J0861_auto
# s2n_J0861_iso
# s2n_J0861_petro
# s2n_g_PStotal
# s2n_g_aper_3
# s2n_g_aper_6
# s2n_g_auto
# s2n_g_iso
# s2n_g_petro
# s2n_i_PStotal
# s2n_i_aper_3
# s2n_i_aper_6
# s2n_i_auto
# s2n_i_iso
# s2n_i_petro
# s2n_r_PStotal
# s2n_r_aper_3
# s2n_r_aper_6
# s2n_r_auto
# s2n_r_iso
# s2n_r_petro
# s2n_u_PStotal
# s2n_u_aper_3
# s2n_u_aper_6
# s2n_u_auto
# s2n_u_iso
# s2n_u_petro
# s2n_z_PStotal
# s2n_z_aper_3
# s2n_z_aper_6
# s2n_z_auto
# s2n_z_iso
# s2n_z_petro
# u_ID_dual
# u_PStotal
# u_aper_3
# u_aper_6
# u_auto
# u_iso
# u_petro
# z_ID_dual
# z_PStotal
# z_aper_3
# z_aper_6
# z_auto
# z_iso
# z_petro
# Norder
# Dir
# Npix
# margin_Norder
# margin_Dir
# margin_Npix

# %%
dual = lsdb.read_hipscat(
                dr4_links[0],
                margin_cache=dr4_margin,
                columns = ["Field", "ID", "RA", "DEC", 
                           "X", "Y", "A", "B", "ELLIPTICITY", "ELONGATION",
                           "FWHM", "KRON_RADIUS", "ISOarea", "MU_MAX_r", "MU_MAX_J0660", "MU_MAX_i", "s2n_DET_PStotal",
                           "s2n_g_PStotal", "s2n_J0515_PStotal", "s2n_r_PStotal", "s2n_J0660_PStotal", "s2n_i_PStotal", 
                            "SEX_FLAGS_DET", "SEX_FLAGS_r", "SEX_FLAGS_J0660", "SEX_FLAGS_i",
                            "r_PStotal", "e_r_PStotal",
                            "g_PStotal", "e_g_PStotal",
                            "i_PStotal", "e_i_PStotal",
                            "u_PStotal", "e_u_PStotal",
                            "z_PStotal", "e_z_PStotal",
                            "J0378_PStotal", "e_J0378_PStotal",
                            "J0395_PStotal", "e_J0395_PStotal",
                            "J0410_PStotal", "e_J0410_PStotal",
                            "J0430_PStotal", "e_J0430_PStotal",
                            "J0515_PStotal", "e_J0515_PStotal",
                            "J0660_PStotal", "e_J0660_PStotal",
                            "J0861_PStotal", "e_J0861_PStotal",]
                                        )

# %% [markdown]
# ### PSF

# %%
dr4_psf = splusdata.get_hipscats("dr4/psf")[0]
psf_margin = lsdb.read_hipscat(dr4_psf[1])
for i in psf_margin.columns:
    print(i)
# Out:
# ID
# RA
# DEC
# CLASS_STAR_J0378
# CLASS_STAR_J0395
# CLASS_STAR_J0410
# CLASS_STAR_J0430
# CLASS_STAR_J0515
# CLASS_STAR_J0660
# CLASS_STAR_J0861
# CLASS_STAR_g
# CLASS_STAR_i
# CLASS_STAR_r
# CLASS_STAR_u
# CLASS_STAR_z
# DoPHOT_Star_number_J0378
# DoPHOT_Star_number_J0395
# DoPHOT_Star_number_J0410
# DoPHOT_Star_number_J0430
# DoPHOT_Star_number_J0515
# DoPHOT_Star_number_J0660
# DoPHOT_Star_number_J0861
# DoPHOT_Star_number_g
# DoPHOT_Star_number_i
# DoPHOT_Star_number_r
# DoPHOT_Star_number_u
# DoPHOT_Star_number_z
# J0378_psf
# J0395_psf
# J0410_psf
# J0430_psf
# J0515_psf
# J0660_psf
# J0861_psf
# X_J0378
# X_J0395
# X_J0410
# X_J0430
# X_J0515
# X_J0660
# X_J0861
# X_g
# X_i
# X_r
# X_u
# X_z
# Y_J0378
# Y_J0395
# Y_J0410
# Y_J0430
# Y_J0515
# Y_J0660
# Y_J0861
# Y_g
# Y_i
# Y_r
# Y_u
# Y_z
# e_J0378_psf
# e_J0395_psf
# e_J0410_psf
# e_J0430_psf
# e_J0515_psf
# e_J0660_psf
# e_J0861_psf
# e_g_psf
# e_i_psf
# e_r_psf
# e_u_psf
# e_z_psf
# g_psf
# i_psf
# r_psf
# s2n_J0378_psf
# s2n_J0395_psf
# s2n_J0410_psf
# s2n_J0430_psf
# s2n_J0515_psf
# s2n_J0660_psf
# s2n_J0861_psf
# s2n_g_psf
# s2n_i_psf
# s2n_r_psf
# s2n_u_psf
# s2n_z_psf
# u_psf
# z_psf
# Norder
# Dir
# Npix
# margin_Norder
# margin_Dir
# margin_Npix

# %%
psf = lsdb.read_hipscat(
       dr4_psf[0],
       margin_cache=psf_margin,
        columns = ["RA", "DEC", "r_psf", "e_r_psf",
                    "g_psf", "e_g_psf",
                    "i_psf", "e_i_psf",
                    "u_psf", "e_u_psf",
                    "z_psf", "e_z_psf",
                    "J0378_psf", "e_J0378_psf",
                    "J0395_psf", "e_J0395_psf",
                    "J0410_psf", "e_J0410_psf",
                    "J0430_psf", "e_J0430_psf",
                    "J0515_psf", "e_J0515_psf",
                    "J0660_psf", "e_J0660_psf",
                    "J0861_psf", "e_J0861_psf",])

# %%
print(psf.columns)
# Out:
# Index(['RA', 'DEC', 'r_psf', 'e_r_psf', 'g_psf', 'e_g_psf', 'i_psf', 'e_i_psf',
#        'u_psf', 'e_u_psf', 'z_psf', 'e_z_psf', 'J0378_psf', 'e_J0378_psf',
#        'J0395_psf', 'e_J0395_psf', 'J0410_psf', 'e_J0410_psf', 'J0430_psf',
#        'e_J0430_psf', 'J0515_psf', 'e_J0515_psf', 'J0660_psf', 'e_J0660_psf',
#        'J0861_psf', 'e_J0861_psf'],
#       dtype='object')

# %% [markdown]
# #### Matching two hipscat tables

# %%
dual_psf = psf.crossmatch(dual, radius_arcsec = 2)

# %% [markdown]
# #### Matching an external table with hipscat

# %%
# GALEX table
df = pd.read_csv("../GUVcat_AISxSDSS_HSmaster.csv") # load your table

# %%
# Scatter the DataFrame to distribute it across workers
df_scattered = client.scatter(df)

# %%
# Load the DataFrame into lsdb
df_hips = lsdb.from_dataframe(df, ra_column="GALEX_RA", dec_column="GALEX_DEC", margin_threshold=3600)
# Out:
# /home/luis/anaconda3/envs/lsdb/lib/python3.12/site-packages/distributed/client.py:3361: UserWarning: Sending large graph of size 183.73 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /home/luis/anaconda3/envs/lsdb/lib/python3.12/site-packages/distributed/client.py:3361: UserWarning: Sending large graph of size 183.73 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /home/luis/anaconda3/envs/lsdb/lib/python3.12/site-packages/distributed/client.py:3361: UserWarning: Sending large graph of size 16.05 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(

# %%
# matching with dual catalog (instantiated earlier)--dual
matched_table_dual = df_hips.crossmatch(dual, radius_arcsec = 2).compute()
# Out:
# /home/luis/anaconda3/envs/lsdb/lib/python3.12/site-packages/distributed/client.py:3361: UserWarning: Sending large graph of size 149.44 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(

# %%
# Save DataFrame to CSV or other formats
matched_table_dual.to_csv("../GUVcat_AISxSDSS_HSmaster-splusDr4-dual-2arcsec-lsdb.csv", index=False)

# %%
# matching with dual catalog (instantiated earlier)--psf
matched_table_psf = df_hips.crossmatch(psf, radius_arcsec = 2).compute()
# Out:
# /home/luis/anaconda3/envs/lsdb/lib/python3.12/site-packages/distributed/client.py:3361: UserWarning: Sending large graph of size 148.84 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(

# %%
# Save DataFrame to CSV or other formats
matched_table_psf.to_csv("../GUVcat_AISxSDSS_HSmaster-splusDr4-psf-2arcsec-lsdb.csv", index=False)
