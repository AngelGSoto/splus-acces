# %%
import lsdb
import splusdata

# %% [markdown]
# Using splusdata we can print the available catalogs, and get the link for one in particular.

# %%
# This will print all available links
print(splusdata.get_hipscats())

# This will get the link for a specific pattern
print(splusdata.get_hipscats("dr4/dual"))
# Out:
# {'dr4_vacs': {'qso_z': {'hipscats': ['qso_z'], 'margins': ['qso_z_2arcsec']}, 'photozs': {'hipscats': ['photozs'], 'margins': ['photozs_2arcsec']}, 'calib_flag': {'hipscats': ['calib_flag'], 'margins': ['calib_flag_2arcsec']}, 'sqg': {'hipscats': ['sqg'], 'margins': ['sqg_2arcsec']}}, 'sdr1': {'hipscats': ['shorts'], 'margins': ['shorts_2arcsec']}, 'dr4': {'hipscats': ['single', 'dual', 'psf'], 'margins': ['psf_2arcsec', 'single_2arcsec', 'dual_2arcsec']}}
# [['https://splus.cloud/HIPS/catalogs/dr4/dual/', 'https://splus.cloud/HIPS/catalogs/dr4/dual_2arcsec/']]

# %% [markdown]
# #### Important
#
# Before getting into the code, start a dask Client with the desired specs, this is what does the "parallel magic". This step is very important. It will also print a url to a dashboard that you can use to check the status of your queries.

# %%
from dask.distributed import Client

client = Client(n_workers=10, memory_limit="8GB")
client
# Out:
# <Client: 'tcp://127.0.0.1:36673' processes=10 threads=20, memory=74.51 GiB>

# %% [markdown]
# #### Exploring the data
#
# Before we start querying the data, let's take a look at the available columns in the catalog. This is important to know what we can query and what we can get from the database. Filtering the columns will make the query faster and more efficient.

# %%
# This will return a list because there may be more than
# one match for dr4/dual
dr4_dual_link = splusdata.get_hipscats("dr4/dual")[0]

# dr4_dual_link will be a tuple, because of the margin link.
dual_link = lsdb.read_hipscat(dr4_dual_link[0])

# %%
list(dual_link.columns)
# Out:
# ['ID',
#  'RA',
#  'DEC',
#  'A',
#  'B',
#  'BACKGROUND',
#  'BACKGROUND_J0378',
#  'BACKGROUND_J0395',
#  'BACKGROUND_J0410',
#  'BACKGROUND_J0430',
#  'BACKGROUND_J0515',
#  'BACKGROUND_J0660',
#  'BACKGROUND_J0861',
#  'BACKGROUND_g',
#  'BACKGROUND_i',
#  'BACKGROUND_r',
#  'BACKGROUND_u',
#  'BACKGROUND_z',
#  'CLASS_STAR',
#  'DET_ID_dual',
#  'EBV_SCH',
#  'ELLIPTICITY',
#  'ELONGATION',
#  'FLUX_RADIUS_20',
#  'FLUX_RADIUS_50',
#  'FLUX_RADIUS_70',
#  'FLUX_RADIUS_90',
#  'FWHM',
#  'FWHM_J0378',
#  'FWHM_J0395',
#  'FWHM_J0410',
#  'FWHM_J0430',
#  'FWHM_J0515',
#  'FWHM_J0660',
#  'FWHM_J0861',
#  'FWHM_g',
#  'FWHM_i',
#  'FWHM_n',
#  'FWHM_n_J0378',
#  'FWHM_n_J0395',
#  'FWHM_n_J0410',
#  'FWHM_n_J0430',
#  'FWHM_n_J0515',
#  'FWHM_n_J0660',
#  'FWHM_n_J0861',
#  'FWHM_n_g',
#  'FWHM_n_i',
#  'FWHM_n_r',
#  'FWHM_n_u',
#  'FWHM_n_z',
#  'FWHM_r',
#  'FWHM_u',
#  'FWHM_z',
#  'Field',
#  'ID_DEC',
#  'ID_RA',
#  'ISOarea',
#  'J0378_ID_dual',
#  'J0378_PStotal',
#  'J0378_aper_3',
#  'J0378_aper_6',
#  'J0378_auto',
#  'J0378_iso',
#  'J0378_petro',
#  'J0395_ID_dual',
#  'J0395_PStotal',
#  'J0395_aper_3',
#  'J0395_aper_6',
#  'J0395_auto',
#  'J0395_iso',
#  'J0395_petro',
#  'J0410_ID_dual',
#  'J0410_PStotal',
#  'J0410_aper_3',
#  'J0410_aper_6',
#  'J0410_auto',
#  'J0410_iso',
#  'J0410_petro',
#  'J0430_ID_dual',
#  'J0430_PStotal',
#  'J0430_aper_3',
#  'J0430_aper_6',
#  'J0430_auto',
#  'J0430_iso',
#  'J0430_petro',
#  'J0515_ID_dual',
#  'J0515_PStotal',
#  'J0515_aper_3',
#  'J0515_aper_6',
#  'J0515_auto',
#  'J0515_iso',
#  'J0515_petro',
#  'J0660_ID_dual',
#  'J0660_PStotal',
#  'J0660_aper_3',
#  'J0660_aper_6',
#  'J0660_auto',
#  'J0660_iso',
#  'J0660_petro',
#  'J0861_ID_dual',
#  'J0861_PStotal',
#  'J0861_aper_3',
#  'J0861_aper_6',
#  'J0861_auto',
#  'J0861_iso',
#  'J0861_petro',
#  'KRON_RADIUS',
#  'MU_MAX_INST',
#  'MU_MAX_J0378',
#  'MU_MAX_J0395',
#  'MU_MAX_J0410',
#  'MU_MAX_J0430',
#  'MU_MAX_J0515',
#  'MU_MAX_J0660',
#  'MU_MAX_J0861',
#  'MU_MAX_g',
#  'MU_MAX_i',
#  'MU_MAX_r',
#  'MU_MAX_u',
#  'MU_MAX_z',
#  'MU_THRESHOLD_INST',
#  'MU_THRESHOLD_J0378',
#  'MU_THRESHOLD_J0395',
#  'MU_THRESHOLD_J0410',
#  'MU_THRESHOLD_J0430',
#  'MU_THRESHOLD_J0515',
#  'MU_THRESHOLD_J0660',
#  'MU_THRESHOLD_J0861',
#  'MU_THRESHOLD_g',
#  'MU_THRESHOLD_i',
#  'MU_THRESHOLD_r',
#  'MU_THRESHOLD_u',
#  'MU_THRESHOLD_z',
#  'PETRO_RADIUS',
#  'PHOT_ID_DEC_dual',
#  'PHOT_ID_RA_dual',
#  'PHOT_ID_dual',
#  'SEX_FLAGS_DET',
#  'SEX_FLAGS_J0378',
#  'SEX_FLAGS_J0395',
#  'SEX_FLAGS_J0410',
#  'SEX_FLAGS_J0430',
#  'SEX_FLAGS_J0515',
#  'SEX_FLAGS_J0660',
#  'SEX_FLAGS_J0861',
#  'SEX_FLAGS_g',
#  'SEX_FLAGS_i',
#  'SEX_FLAGS_r',
#  'SEX_FLAGS_u',
#  'SEX_FLAGS_z',
#  'SEX_NUMBER_DET',
#  'SEX_NUMBER_J0378',
#  'SEX_NUMBER_J0395',
#  'SEX_NUMBER_J0410',
#  'SEX_NUMBER_J0430',
#  'SEX_NUMBER_J0515',
#  'SEX_NUMBER_J0660',
#  'SEX_NUMBER_J0861',
#  'SEX_NUMBER_g',
#  'SEX_NUMBER_i',
#  'SEX_NUMBER_r',
#  'SEX_NUMBER_u',
#  'SEX_NUMBER_z',
#  'THETA',
#  'THRESHOLD',
#  'THRESHOLD_J0378',
#  'THRESHOLD_J0395',
#  'THRESHOLD_J0410',
#  'THRESHOLD_J0430',
#  'THRESHOLD_J0515',
#  'THRESHOLD_J0660',
#  'THRESHOLD_J0861',
#  'THRESHOLD_g',
#  'THRESHOLD_i',
#  'THRESHOLD_r',
#  'THRESHOLD_u',
#  'THRESHOLD_z',
#  'X',
#  'Y',
#  'calib_strat',
#  'e_J0378_PStotal',
#  'e_J0378_aper_3',
#  'e_J0378_aper_6',
#  'e_J0378_auto',
#  'e_J0378_iso',
#  'e_J0378_petro',
#  'e_J0395_PStotal',
#  'e_J0395_aper_3',
#  'e_J0395_aper_6',
#  'e_J0395_auto',
#  'e_J0395_iso',
#  'e_J0395_petro',
#  'e_J0410_PStotal',
#  'e_J0410_aper_3',
#  'e_J0410_aper_6',
#  'e_J0410_auto',
#  'e_J0410_iso',
#  'e_J0410_petro',
#  'e_J0430_PStotal',
#  'e_J0430_aper_3',
#  'e_J0430_aper_6',
#  'e_J0430_auto',
#  'e_J0430_iso',
#  'e_J0430_petro',
#  'e_J0515_PStotal',
#  'e_J0515_aper_3',
#  'e_J0515_aper_6',
#  'e_J0515_auto',
#  'e_J0515_iso',
#  'e_J0515_petro',
#  'e_J0660_PStotal',
#  'e_J0660_aper_3',
#  'e_J0660_aper_6',
#  'e_J0660_auto',
#  'e_J0660_iso',
#  'e_J0660_petro',
#  'e_J0861_PStotal',
#  'e_J0861_aper_3',
#  'e_J0861_aper_6',
#  'e_J0861_auto',
#  'e_J0861_iso',
#  'e_J0861_petro',
#  'e_g_PStotal',
#  'e_g_aper_3',
#  'e_g_aper_6',
#  'e_g_auto',
#  'e_g_iso',
#  'e_g_petro',
#  'e_i_PStotal',
#  'e_i_aper_3',
#  'e_i_aper_6',
#  'e_i_auto',
#  'e_i_iso',
#  'e_i_petro',
#  'e_r_PStotal',
#  'e_r_aper_3',
#  'e_r_aper_6',
#  'e_r_auto',
#  'e_r_iso',
#  'e_r_petro',
#  'e_u_PStotal',
#  'e_u_aper_3',
#  'e_u_aper_6',
#  'e_u_auto',
#  'e_u_iso',
#  'e_u_petro',
#  'e_z_PStotal',
#  'e_z_aper_3',
#  'e_z_aper_6',
#  'e_z_auto',
#  'e_z_iso',
#  'e_z_petro',
#  'g_ID_dual',
#  'g_PStotal',
#  'g_aper_3',
#  'g_aper_6',
#  'g_auto',
#  'g_iso',
#  'g_petro',
#  'i_ID_dual',
#  'i_PStotal',
#  'i_aper_3',
#  'i_aper_6',
#  'i_auto',
#  'i_iso',
#  'i_petro',
#  'r_ID_dual',
#  'r_PStotal',
#  'r_aper_3',
#  'r_aper_6',
#  'r_auto',
#  'r_iso',
#  'r_petro',
#  's2n_DET_PStotal',
#  's2n_DET_aper_3',
#  's2n_DET_aper_6',
#  's2n_DET_auto',
#  's2n_DET_iso',
#  's2n_DET_petro',
#  's2n_J0378_PStotal',
#  's2n_J0378_aper_3',
#  's2n_J0378_aper_6',
#  's2n_J0378_auto',
#  's2n_J0378_iso',
#  's2n_J0378_petro',
#  's2n_J0395_PStotal',
#  's2n_J0395_aper_3',
#  's2n_J0395_aper_6',
#  's2n_J0395_auto',
#  's2n_J0395_iso',
#  's2n_J0395_petro',
#  's2n_J0410_PStotal',
#  's2n_J0410_aper_3',
#  's2n_J0410_aper_6',
#  's2n_J0410_auto',
#  's2n_J0410_iso',
#  's2n_J0410_petro',
#  's2n_J0430_PStotal',
#  's2n_J0430_aper_3',
#  's2n_J0430_aper_6',
#  's2n_J0430_auto',
#  's2n_J0430_iso',
#  's2n_J0430_petro',
#  's2n_J0515_PStotal',
#  's2n_J0515_aper_3',
#  's2n_J0515_aper_6',
#  's2n_J0515_auto',
#  's2n_J0515_iso',
#  's2n_J0515_petro',
#  's2n_J0660_PStotal',
#  's2n_J0660_aper_3',
#  's2n_J0660_aper_6',
#  's2n_J0660_auto',
#  's2n_J0660_iso',
#  's2n_J0660_petro',
#  's2n_J0861_PStotal',
#  's2n_J0861_aper_3',
#  's2n_J0861_aper_6',
#  's2n_J0861_auto',
#  's2n_J0861_iso',
#  's2n_J0861_petro',
#  's2n_g_PStotal',
#  's2n_g_aper_3',
#  's2n_g_aper_6',
#  's2n_g_auto',
#  's2n_g_iso',
#  's2n_g_petro',
#  's2n_i_PStotal',
#  's2n_i_aper_3',
#  's2n_i_aper_6',
#  's2n_i_auto',
#  's2n_i_iso',
#  's2n_i_petro',
#  's2n_r_PStotal',
#  's2n_r_aper_3',
#  's2n_r_aper_6',
#  's2n_r_auto',
#  's2n_r_iso',
#  's2n_r_petro',
#  's2n_u_PStotal',
#  's2n_u_aper_3',
#  's2n_u_aper_6',
#  's2n_u_auto',
#  's2n_u_iso',
#  's2n_u_petro',
#  's2n_z_PStotal',
#  's2n_z_aper_3',
#  's2n_z_aper_6',
#  's2n_z_auto',
#  's2n_z_iso',
#  's2n_z_petro',
#  'u_ID_dual',
#  'u_PStotal',
#  'u_aper_3',
#  'u_aper_6',
#  'u_auto',
#  'u_iso',
#  'u_petro',
#  'z_ID_dual',
#  'z_PStotal',
#  'z_aper_3',
#  'z_aper_6',
#  'z_auto',
#  'z_iso',
#  'z_petro',
#  'Norder',
#  'Dir',
#  'Npix']

# %% [markdown]
# ### Querying the data
#
# Here we will show some examples of queries that can be done with LSDB. We will show how to filter the columns and how to filter the data.
#
# First we will instantiate the LSDB object with the catalog we want to query. Then we will use a conesearch or box_search method to get the data we want.
#
# Let's start with DR4.

# %%
dr4_links = splusdata.get_hipscats("dr4/dual")[0]

dual_margin = lsdb.read_hipscat(dr4_links[1])
dual = lsdb.read_hipscat(
    dr4_links[0],
    margin_cache=dual_margin,
    columns=["ID", "RA", "DEC", 
             "r_auto", "g_auto", "i_auto", "z_auto", "u_auto",
             "J0378_auto", "J0395_auto", "J0410_auto", "J0430_auto",
# 4899280014878441472   18.510283   17.860935   17.489532
# ...                         ...         ...         ...
# 5477015167298437120   14.894634   14.849438   14.831547
# 5477019443450085376   17.059698   16.627821   16.473158
# 5477019576694734848   16.486736   16.147192   15.973917
# 5477082479728787456   18.383245   17.797897   17.340208
# 5477085362889162752   14.641972   14.329616   14.181574
#
# [3688 rows x 15 columns]

# %% [markdown]
# ### Matching hipscat tables
#
# Assuming you have the the table from the example before, lets instantiate a new hipscat object pointing to another table, in this case Star Galaxy Quasar (sqg) separation table, and make a match with the dual catalog.
#
# First lets instantiate the hipscat that we want to match with the dual catalog. In this case we are using the sqg table.

# %%
dr4_sqg = splusdata.get_hipscats("dr4/sqg")[0]
sqg_margin = lsdb.read_hipscat(dr4_sqg[1])
sqg = lsdb.read_hipscat(
    dr4_sqg[0],
    margin_cache=sqg_margin,
    filters=[("PROB_GAL", ">", 0.8)]
)
# Out:
# /home/luis/anaconda3/envs/myenv/lib/python3.12/site-packages/hipscat/io/file_io/file_io.py:320: UserWarning: point_map.fits file written in RING ordering, due to https://github.com/astronomy-commons/hipscat/issues/271. Converting to NESTED.
#   warnings.warn(

# %%
dual_sqg = sqg.crossmatch(
    dual, radius_arcsec = 1
)

# %%
result_table = dual_sqg.cone_search(
    1, #ra
    1, #dec
    1 * 3600 # radius in arcsecs
).compute()

# %%
result_table
# Out:
#                                           ID_sqg    RA_sqg   DEC_sqg  \
# _hipscat_index
# 5091982615334879232  DR4_3_STRIPE82-0003_0027945  1.150865  0.028838
# 5091982615334879233  DR4_3_STRIPE82-0004_0000309  1.150864  0.028841
# 5091984044355223552  DR4_3_STRIPE82-0003_0032189  1.204843  0.022827
# 5091985502148493312  DR4_3_STRIPE82-0004_0002515  1.293757   0.09462
# 5091996295271284736  DR4_3_STRIPE82-0003_0041728  0.935803  0.038474
# ...                                          ...       ...       ...
# 5477516506839384064  DR4_3_STRIPE82-0004_0031617  1.408031  1.376836
# 5477522346325573632  DR4_3_STRIPE82-0004_0030245  1.605574  1.412259
# 5477523454678794240  DR4_3_STRIPE82-0004_0030129  1.515884  1.415197
# 5477538455980343296  DR4_3_STRIPE82-0004_0031945  1.237745  1.368443
# 5477539228738912256  DR4_3_STRIPE82-0004_0030805  1.215805   1.39588
#
#                      CLASS_sqg model_flag_sqg  PROB_QSO_sqg  PROB_STAR_sqg  \
# _hipscat_index
# 5091982615334879232        2.0              0           0.0            0.0
# 5091982615334879233        2.0              0           0.0           0.01
# 5091984044355223552        2.0              0           0.0            0.0
# 5091985502148493312        2.0              0           0.0            0.0
# 5091996295271284736        2.0              1           0.0           0.03
# ...                        ...            ...           ...            ...
# 5477516506839384064        2.0              0           0.0            0.0
# 5477522346325573632        2.0              0           0.0            0.0
# 5477523454678794240        2.0              0           0.0            0.0
# 5477538455980343296        2.0              0           0.0            0.0
# 5477539228738912256        2.0              0          0.01            0.0
#
#                      PROB_GAL_sqg  Norder_sqg  Dir_sqg  ...  z_auto_dual  \
# _hipscat_index                                          ...
# 5091982615334879232           1.0           5        0  ...     16.79575
# 5091982615334879233          0.99           5        0  ...    16.846527
# 5091984044355223552           1.0           5        0  ...     16.89802
# 5091985502148493312           1.0           5        0  ...    16.339067
# 5091996295271284736          0.97           5        0  ...    17.094036
# ...                           ...         ...      ...  ...          ...
# 5477516506839384064           1.0           1        0  ...    17.315907
# 5477522346325573632           1.0           1        0  ...    17.270304
# 5477523454678794240           1.0           1        0  ...    17.266359
# 5477538455980343296           1.0           1        0  ...    16.958735
# 5477539228738912256          0.99           1        0  ...    17.223598
#
#                     u_auto_dual  J0378_auto_dual  J0395_auto_dual  \
# _hipscat_index
# 5091982615334879232   19.050779        18.839561        17.938129
# 5091982615334879233        99.0        21.545265             99.0
# 5091984044355223552   18.517649        18.489357        17.876053
# 5091985502148493312   19.679325        19.227543        18.749567
# 5091996295271284736        99.0             99.0             99.0
# ...                         ...              ...              ...
# 5477516506839384064   19.482903        19.000202         18.59066
# 5477522346325573632   20.656267        19.574299        19.082758
# 5477523454678794240   19.315477        19.244976             99.0
# 5477538455980343296   19.771029        19.629147        19.452023
# 5477539228738912256   22.927433        19.337631        19.314798
#
#                      J0410_auto_dual  J0430_auto_dual  J0515_auto_dual  \
# _hipscat_index
# 5091982615334879232        18.594076        18.210499        17.890163
# 5091982615334879233        20.170612        21.277454        18.713846
# 5091984044355223552         17.87262        18.106815        17.605772
# 5091985502148493312        19.539658        18.906784        17.509869
# 5091996295271284736         21.31982             99.0         19.08293
# ...                              ...              ...              ...
# 5477516506839384064        18.672577        18.517576        17.878046
# 5477522346325573632        19.064711        18.794336        18.104109
# 5477523454678794240        20.037548        19.005175        18.162382
# 5477538455980343296        20.194883         19.03417        18.233887
# 5477539228738912256        19.636276        18.916636        19.094917
#
#                      J0660_auto_dual  J0861_auto_dual  _dist_arcsec
# _hipscat_index
# 5091982615334879232        17.360659        16.743773      0.000282
# 5091982615334879233        17.550707        16.940117      0.000282
# 5091984044355223552        17.325048        16.743799      0.000282
# 5091985502148493312        16.961966        16.473761      0.000282
# 5091996295271284736        17.274836        17.269068      0.000282
# ...                              ...              ...           ...
# 5477516506839384064        17.745064         17.27664      0.000282
# 5477522346325573632        17.721167        17.305927      0.000282
# 5477523454678794240        17.910954        17.321766      0.000282
# 5477538455980343296        17.491346        17.097546      0.000282
# 5477539228738912256        17.800262        17.117435      0.000282
#
# [492 rows x 27 columns]

# %% [markdown]
# Now imagine that we want to match our dual_sqg table with gaia dr3. We can do the same thing, instantiate a new hipscat object with the gaia dr3 table and use the match method to match the sources.
#
# Luckily some already partitioned catalogs are available at lsdb.io. We can use them to match with our dual catalog.

# %%
gaia = lsdb.read_hipscat('https://data.lsdb.io/unstable/gaia_dr3/gaia/')

dual_gaia_sqg = dual_sqg.crossmatch(
    gaia, radius_arcsec=1
)
# Out:
# /home/luis/anaconda3/envs/myenv/lib/python3.12/site-packages/lsdb/dask/crossmatch_catalog_data.py:108: RuntimeWarning: Right catalog does not have a margin cache. Results may be incomplete and/or inaccurate.
#   warnings.warn(
