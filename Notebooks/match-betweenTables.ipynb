# %%
import pandas as pd
from astropy.table import Table, Column, MaskedColumn
from astropy.coordinates import SkyCoord
from astropy import units as u
import astropy.coordinates as coord
import numpy as np

# %%
# load your tables pandas
df_dual = pd.read_csv("../GUVcat_AISxSDSS_HSmaster-splusDr4-dualPsf-2arcsec-lsdb.csv") # load your table
len( df_dual )
# Out:
# 2266

# %%
for i in df_dual.columns:
    print(i)
# Out:
# GALEX_ID__1
# PHOTOEXTRACTID__1
# MPSTYPE__1
# AVASPRA__1
# AVASPDEC__1
# FEXPTIME__1
# NEXPTIME__1
# GALEX_RA__1
# GALEX_DEC__1
# GALEX_GLON__1
# GALEX_GLAT__1
# TILENUM__1
# IMG__1
# SUBVISIT__1
# FOV_RADIUS__1
# GALEX_TYPE__1
# BAND__1
# E_BV__1
# ISTHERESPECTRUM__1
# CHKOBJ_TYPE__1
# FUV_MAG__1
# FUV_MAGERR__1
# NUV_MAG__1
# NUV_MAGERR__1
# FUV_MAG_AUTO__1
# FUV_MAGERR_AUTO__1
# NUV_MAG_AUTO__1
# NUV_MAGERR_AUTO__1
# FUV_MAG_APER_4__1
# FUV_MAGERR_APER_4__1
# NUV_MAG_APER_4__1
# NUV_MAGERR_APER_4__1
# FUV_MAG_APER_6__1
# FUV_MAGERR_APER_6__1
# NUV_MAG_APER_6__1
# NUV_MAGERR_APER_6__1
# FUV_ARTIFACT__1
# NUV_ARTIFACT__1
# FUV_FLAGS__1
# NUV_FLAGS__1
# FUV_FLUX__1
# FUV_FLUXERR__1
# NUV_FLUX__1
# NUV_FLUXERR__1
# FUV_X_IMAGE__1
# FUV_Y_IMAGE__1
# NUV_X_IMAGE__1
# NUV_Y_IMAGE__1
# FUV_FWHM_IMAGE__1
# NUV_FWHM_IMAGE__1
# FUV_FWHM_WORLD__1
# NUV_FWHM_WORLD__1
# NUV_CLASS_STAR__1
# FUV_CLASS_STAR__1
# NUV_ELLIPTICITY__1
# FUV_ELLIPTICITY__1
# NUV_THETA_J2000__1
# NUV_ERRTHETA_J2000__1
# ...

# %%
# List of columns you want to keep
columns_to_keep = [
    'GALEX_ID__1', 'PHOTOEXTRACTID__1', 'MPSTYPE__1', 'AVASPRA__1', 'AVASPDEC__1', 'FEXPTIME__1',
    'NEXPTIME__1', 'TILENUM__1', 'IMG__1', 'SUBVISIT__1', 'FOV_RADIUS__1', 'BAND__1', 'E_BV__1', 
    'ISTHERESPECTRUM__1', 'CHKOBJ_TYPE__1', 'FUV_MAG__1', 'NUV_MAG__1', 'PROB__1', 'SEP__1',
    'IB_POSERR__1', 'CORV__1', 'GRANK__1', 'NGRANK__1', 'PRIMGID__1', 'GROUPGID__1', 'GRANKDIST__1',
    'NGRANKDIST__1', 'PRIMGIDDIST__1', 'GROUPGIDDIST__1', 'GROUPGIDTOT__1', 'DIFFFUV__1',
    'DIFFNUV__1', 'DIFFFUVDIST__1', 'DIFFNUVDIST__1', 'SEPAS__1', 'SEPASDIST__1', 'INLARGEOBJ__1',
    'LARGEOBJSIZE__1', 'SDSS_ID__1', 'NCHILD__1', 'PSFMAG_U__1', 'PSFMAGERR_U__1', 'EXPMAG_U__1',
    'EXPMAGERR_U__1', 'EXPAB_U__1', 'EXPABERR_U__1', 'DEVMAG_U__1', 'DEVMAGERR_U__1', 'DEVAB_U__1',
    'DEVABERR_U__1', 'PETROMAG_U__1', 'PETROMAGERR_U__1', 'FLAGS1__1', 'FLAGS2__1', 'FLAGS_U__1',
    'EDGE__1', 'U_SAT__1', 'G_SAT__1', 'R_SAT__1', 'I_SAT__1', 'Z_SAT__1', 'PROBPSF_U__1', 
    'PSFFWHM_U__1', 'SPECOBJ_ID__1', 'PLATE__1', 'MJD__1', 'FIBER_ID__1', 'REDSHIFT__1', 
    'REDSHIFTERR__1', 'SPECTYPE__1', 'CLASS__1', 'SUBCLASS__1', 'ELODIESPTYPE__1', 'B_V_COLOR__1',
    'TEFF__1', 'LOGG__1', 'METALLICITY__1', 'ELODIE_REDSHIFT__1', 'PROPERMOTION__1', 'USNO_RED1__1',
    'RUN__1', 'RERUN__1', 'CAMCOL__1', 'FIELD__1', 'DSTARCSEC__1', 'DISTANCERANK__1', 
    'REVERSEDISTANCERANK__1', 'MULTIPLEMATCHCOUNT__1', 'REVERSEMULTIPLEMATCHCOUNT__1', 
    'SIMBAD_MATCH_NEAREST__1', 'NSIMBADMATCHES5AS__1', 'NSIMBADMATCHES10AS__1', 'GAIA_ID__1', 
    'DISTARCMIN__1', 'PARALLAX__1', 'PM__1', 'PMRA__1', 'PMDEC__1', 'ASTROMETRIC_N_GOOD_OBS_AL__1',
    'RUWE__1', 'DUPLICATED_SOURCE__1', 'PHOT_G_MEAN_MAG__1', 'RADIAL_VELOCITY__1',
    'VARI_SUMMARY_GAIA_ID__1', 'NON_SINGLE_STAR__1', 'IN_QSO_CANDIDATES__1', 'MIN_MAG_G_FOV__1', 
    'MAX_MAG_G_FOV__1', 'MEAN_MAG_G_FOV__1', 'MEDIAN_MAG_G_FOV__1', 'RANGE_MAG_G_FOV__1', 
    'TRIMMED_RANGE_MAG_G_FOV__1', 'STD_DEV_MAG_G_FOV__1', 'SKEWNESS_MAG_G_FOV__1', 
    'KURTOSIS_MAG_G_FOV__1', 'SEPBACK_ARCSEC__1', 'MMRANK_GAIA__1', 'RMMRANK_GAIA__1', 
    'NMMRANK_GAIA__1', 'RNMMRANK_GAIA__1', 'DISTANCE_GAIA_PC__1', 'Norder__1', 'Dir__1', 'Npix__1',
    'Field_dual', 'ID_dual', 'RA_dual', 'DEC_dual', 'X_dual', 'Y_dual', 'A_dual', 'ELLIPTICITY_dual',
    'ELONGATION_dual', 'FWHM_dual', 'KRON_RADIUS_dual', 'ISOarea_dual', 'MU_MAX_r_dual', 
    's2n_DET_PStotal_dual', 'SEX_FLAGS_DET_dual', 'r_PStotal_dual', 'e_r_PStotal_dual', 
    'g_PStotal_dual', 'i_PStotal_dual', 'u_PStotal_dual', 'z_PStotal_dual', 'J0378_PStotal_dual', 
    'J0395_PStotal_dual', 'J0410_PStotal_dual', 'J0430_PStotal_dual', 'J0515_PStotal_dual', 
    'J0660_PStotal_dual', 'J0861_PStotal_dual', 
]

# %%
# New columns to add
new_columns = [
    'RA_psf', 'DEC_psf', 'r_psf_psf', 'e_r_psf_psf', 'g_psf_psf', 'e_g_psf_psf',
    'i_psf_psf', 'e_i_psf_psf', 'u_psf_psf', 'e_u_psf_psf', 'z_psf_psf', 'e_z_psf_psf',
    'J0378_psf_psf', 'e_J0378_psf_psf', 'J0395_psf_psf', 'e_J0395_psf_psf',
    'J0410_psf_psf', 'e_J0410_psf_psf', 'J0430_psf_psf', 'e_J0430_psf_psf',
    'J0515_psf_psf', 'e_J0515_psf_psf', 'J0660_psf_psf', 'e_J0660_psf_psf',
    'J0861_psf_psf', 'e_J0861_psf_psf'
]

# %%
# Adding the new columns to the existing list
columns_to_keep.extend(new_columns)

# %%
columns_to_keep
# Out:
# ['GALEX_ID__1',
#  'PHOTOEXTRACTID__1',
#  'MPSTYPE__1',
#  'AVASPRA__1',
#  'AVASPDEC__1',
#  'FEXPTIME__1',
#  'NEXPTIME__1',
#  'TILENUM__1',
#  'IMG__1',
#  'SUBVISIT__1',
#  'FOV_RADIUS__1',
#  'BAND__1',
#  'E_BV__1',
#  'ISTHERESPECTRUM__1',
#  'CHKOBJ_TYPE__1',
#  'FUV_MAG__1',
#  'NUV_MAG__1',
#  'PROB__1',
#  'SEP__1',
#  'IB_POSERR__1',
#  'CORV__1',
#  'GRANK__1',
#  'NGRANK__1',
#  'PRIMGID__1',
#  'GROUPGID__1',
#  'GRANKDIST__1',
#  'NGRANKDIST__1',
#  'PRIMGIDDIST__1',
#  'GROUPGIDDIST__1',
#  'GROUPGIDTOT__1',
#  'DIFFFUV__1',
#  'DIFFNUV__1',
#  'DIFFFUVDIST__1',
#  'DIFFNUVDIST__1',
#  'SEPAS__1',
#  'SEPASDIST__1',
#  'INLARGEOBJ__1',
#  'LARGEOBJSIZE__1',
#  'SDSS_ID__1',
#  'NCHILD__1',
#  'PSFMAG_U__1',
#  'PSFMAGERR_U__1',
#  'EXPMAG_U__1',
#  'EXPMAGERR_U__1',
#  'EXPAB_U__1',
#  'EXPABERR_U__1',
#  'DEVMAG_U__1',
#  'DEVMAGERR_U__1',
#  'DEVAB_U__1',
#  'DEVABERR_U__1',
#  'PETROMAG_U__1',
#  'PETROMAGERR_U__1',
#  'FLAGS1__1',
#  'FLAGS2__1',
# ...

# %%
cleaned_df=  df_dual[columns_to_keep]

# %%
cleaned_df
# Out:
#               GALEX_ID__1    PHOTOEXTRACTID__1 MPSTYPE__1  AVASPRA__1  \
# 0     6377249041250518582  6377249041247371264        AIS     45.2781
# 1     6377249018701940387  6377249018698792960        AIS     43.6859
# 2     6377249041250520699  6377249041247371264        AIS     45.2781
# 3     6377249041250520498  6377249041247371264        AIS     45.2781
# 4     6377249041250519444  6377249041247371264        AIS     45.2781
# ...                   ...                  ...        ...         ...
# 2261  6379535937389465454  6379535937386315776        AIS    314.6520
# 2262  6379535937389465162  6379535937386315776        AIS    314.6520
# 2263  6379535937389465702  6379535937386315776        AIS    314.6520
# 2264  6379535937389465518  6379535937386315776        AIS    314.6520
# 2265  6379430479836219316  6379430479833071616        AIS    314.1640
#
#       AVASPDEC__1  FEXPTIME__1  NEXPTIME__1  TILENUM__1  IMG__1  SUBVISIT__1  \
# ...

# %%
for i in cleaned_df.columns:
    print(i)
# Out:
# GALEX_ID__1
# PHOTOEXTRACTID__1
# MPSTYPE__1
# AVASPRA__1
# AVASPDEC__1
# FEXPTIME__1
# NEXPTIME__1
# TILENUM__1
# IMG__1
# SUBVISIT__1
# FOV_RADIUS__1
# BAND__1
# E_BV__1
# ISTHERESPECTRUM__1
# CHKOBJ_TYPE__1
# FUV_MAG__1
# NUV_MAG__1
# PROB__1
# SEP__1
# IB_POSERR__1
# CORV__1
# GRANK__1
# NGRANK__1
# PRIMGID__1
# GROUPGID__1
# GRANKDIST__1
# NGRANKDIST__1
# PRIMGIDDIST__1
# GROUPGIDDIST__1
# GROUPGIDTOT__1
# DIFFFUV__1
# DIFFNUV__1
# DIFFFUVDIST__1
# DIFFNUVDIST__1
# SEPAS__1
# SEPASDIST__1
# INLARGEOBJ__1
# LARGEOBJSIZE__1
# SDSS_ID__1
# NCHILD__1
# PSFMAG_U__1
# PSFMAGERR_U__1
# EXPMAG_U__1
# EXPMAGERR_U__1
# EXPAB_U__1
# EXPABERR_U__1
# DEVMAG_U__1
# DEVMAGERR_U__1
# DEVAB_U__1
# DEVABERR_U__1
# PETROMAG_U__1
# PETROMAGERR_U__1
# FLAGS1__1
# FLAGS2__1
# FLAGS_U__1
# EDGE__1
# U_SAT__1
# G_SAT__1
# R_SAT__1
# I_SAT__1
# Z_SAT__1
# PROBPSF_U__1
# PSFFWHM_U__1
# SPECOBJ_ID__1
# PLATE__1
# MJD__1
# FIBER_ID__1
# REDSHIFT__1
# REDSHIFTERR__1
# SPECTYPE__1
# CLASS__1
# SUBCLASS__1
# ...

# %%
# Remove the "__1" suffix from the column names
cleaned_df.columns = cleaned_df.columns.str.replace('__1', '', regex=False)

# %%
cleaned_df
# Out:
#                  GALEX_ID       PHOTOEXTRACTID MPSTYPE   AVASPRA  AVASPDEC  \
# 0     6377249041250518582  6377249041247371264     AIS   45.2781  0.383599
# 1     6377249018701940387  6377249018698792960     AIS   43.6859  1.290610
# 2     6377249041250520699  6377249041247371264     AIS   45.2781  0.383599
# 3     6377249041250520498  6377249041247371264     AIS   45.2781  0.383599
# 4     6377249041250519444  6377249041247371264     AIS   45.2781  0.383599
# ...                   ...                  ...     ...       ...       ...
# 2261  6379535937389465454  6379535937386315776     AIS  314.6520 -1.262600
# 2262  6379535937389465162  6379535937386315776     AIS  314.6520 -1.262600
# 2263  6379535937389465702  6379535937386315776     AIS  314.6520 -1.262600
# 2264  6379535937389465518  6379535937386315776     AIS  314.6520 -1.262600
# 2265  6379430479836219316  6379430479833071616     AIS  314.1640 -0.439905
#
# ...

# %%
# Save DataFrame to CSV or other formats
cleaned_df.to_csv("../GUVcat_AISxSDSS_HSmaster-splusDr4-dualPsf-2arcsec-lsdb-v2.csv", index=False)

# %% [markdown]
# # Halpha emitters

# %%
df_Ha = pd.read_csv("../GUVcat_AISxSDSS_HSmaster-splusDr4-2arcsec-Halpha.csv") # load your table

# %%
df_Ha
# Out:
#               GALEX_ID       PHOTOEXTRACTID MPSTYPE   AVASPRA  AVASPDEC  \
# 0  6376686003250268630  6376686003247120384     AIS  357.9550 -0.498442
# 1  6376158325715764977  6376158325712617472     AIS  349.5770  1.308610
# 2  6376404583034391236  6376404583031242752     AIS  330.6550  1.328250
# 3  6376580529590896360  6376580529587748864     AIS  321.9610 -1.191970
# 4  6377108311278358050  6377108311275208704     AIS   53.7649 -0.374250
# 5  6377284131133325743  6377284131130179584     AIS   46.3400  0.325212
# 6  6379184089373610179  6379184089370460160     AIS  208.8810 -7.229600
#
#    FEXPTIME  NEXPTIME  TILENUM   IMG  SUBVISIT  ...  e_J0410_psf  J0430_psf  \
# 0    112.00    112.00    50164   321        10  ...        0.049  17.684843
# 1    192.00    192.00    50149  2945        92  ...          NaN  14.587456
# 2    360.00    360.00    50156  1953        61  ...        0.021  16.610163
# 3    192.00    192.00    50161  2689        84  ...        0.060  18.616020
# ...

# %%
for i in df_Ha.columns:
    print(i)
# Out:
# GALEX_ID
# PHOTOEXTRACTID
# MPSTYPE
# AVASPRA
# AVASPDEC
# FEXPTIME
# NEXPTIME
# TILENUM
# IMG
# SUBVISIT
# FOV_RADIUS
# BAND
# E_BV
# ISTHERESPECTRUM
# CHKOBJ_TYPE
# FUV_MAG
# NUV_MAG
# PROB
# SEP
# IB_POSERR
# CORV
# GRANK
# NGRANK
# PRIMGID
# GROUPGID
# GRANKDIST
# NGRANKDIST
# PRIMGIDDIST
# GROUPGIDDIST
# GROUPGIDTOT
# DIFFFUV
# DIFFNUV
# DIFFFUVDIST
# DIFFNUVDIST
# SEPAS
# SEPASDIST
# INLARGEOBJ
# LARGEOBJSIZE
# SDSS_ID
# NCHILD
# PSFMAG_U
# PSFMAGERR_U
# EXPMAG_U
# EXPMAGERR_U
# EXPAB_U
# EXPABERR_U
# DEVMAG_U
# DEVMAGERR_U
# DEVAB_U
# DEVABERR_U
# PETROMAG_U
# PETROMAGERR_U
# FLAGS1
# FLAGS2
# FLAGS_U
# EDGE
# U_SAT
# G_SAT
# R_SAT
# I_SAT
# Z_SAT
# PROBPSF_U
# PSFFWHM_U
# SPECOBJ_ID
# PLATE
# MJD
# FIBER_ID
# REDSHIFT
# REDSHIFTERR
# SPECTYPE
# CLASS
# SUBCLASS
# ELODIESPTYPE
# B_V_COLOR
# TEFF
# LOGG
# METALLICITY
# ELODIE_REDSHIFT
# PROPERMOTION
# USNO_RED1
# RUN
# RERUN
# CAMCOL
# FIELD_1
# DSTARCSEC
# DISTANCERANK
# REVERSEDISTANCERANK
# MULTIPLEMATCHCOUNT
# ...

# %%
keep_columns = [
"GALEX_ID",
"PHOTOEXTRACTID",
"MPSTYPE",
"AVASPRA",
"AVASPDEC",
"FEXPTIME",
"NEXPTIME",
"TILENUM",
"IMG",
"SUBVISIT",
"FOV_RADIUS",
"BAND",
"E_BV",
"ISTHERESPECTRUM",
"CHKOBJ_TYPE",
"FUV_MAG",
"NUV_MAG",
"PROB",
"SEP",
"IB_POSERR",
"CORV",
"GRANK",
"NGRANK",
"PRIMGID",
"GROUPGID",
"GRANKDIST",
"NGRANKDIST",
"PRIMGIDDIST",
"GROUPGIDDIST",
"GROUPGIDTOT",
"DIFFFUV",
"DIFFNUV",
"DIFFFUVDIST",
"DIFFNUVDIST",
"SEPAS",
"SEPASDIST",
"INLARGEOBJ",
"LARGEOBJSIZE",
"SDSS_ID",
"NCHILD",
"PSFMAG_U",
"PSFMAGERR_U",
"EXPMAG_U",
"EXPMAGERR_U",
"EXPAB_U",
"EXPABERR_U",
"DEVMAG_U",
"DEVMAGERR_U",
"DEVAB_U",
"DEVABERR_U",
"PETROMAG_U",
"PETROMAGERR_U",
"FLAGS1",
"FLAGS2",
"FLAGS_U",
"EDGE",
"U_SAT",
"G_SAT",
"R_SAT",
"I_SAT",
"Z_SAT",
"PROBPSF_U",
"PSFFWHM_U",
"SPECOBJ_ID",
"PLATE",
"MJD",
"FIBER_ID",
"REDSHIFT",
"REDSHIFTERR",
"SPECTYPE",
"CLASS",
"SUBCLASS",
"ELODIESPTYPE",
"B_V_COLOR",
"TEFF",
"LOGG",
"METALLICITY",
"ELODIE_REDSHIFT",
"PROPERMOTION",
"USNO_RED1",
"RUN",
"RERUN",
"CAMCOL",
"FIELD_1",
"DSTARCSEC",
"DISTANCERANK",
"REVERSEDISTANCERANK",
"MULTIPLEMATCHCOUNT",
"REVERSEMULTIPLEMATCHCOUNT",
"SIMBAD_MATCH_NEAREST",
"NSIMBADMATCHES5AS",
"NSIMBADMATCHES10AS",
"GAIA_ID",
"DISTARCMIN",
"PARALLAX",
"PM",
"PMRA",
"PMDEC",
"ASTROMETRIC_N_GOOD_OBS_AL",
"RUWE",
"DUPLICATED_SOURCE",
"PHOT_G_MEAN_MAG",
"RADIAL_VELOCITY",
"VARI_SUMMARY_GAIA_ID",
"NON_SINGLE_STAR",
"IN_QSO_CANDIDATES",
"MIN_MAG_G_FOV",
"MAX_MAG_G_FOV",
"MEAN_MAG_G_FOV",
"MEDIAN_MAG_G_FOV",
"RANGE_MAG_G_FOV",
"TRIMMED_RANGE_MAG_G_FOV",
"STD_DEV_MAG_G_FOV",
"SKEWNESS_MAG_G_FOV",
"KURTOSIS_MAG_G_FOV",
"SEPBACK_ARCSEC",
"MMRANK_GAIA",
"RMMRANK_GAIA",
"NMMRANK_GAIA",
"RNMMRANK_GAIA",
"DISTANCE_GAIA_PC",
"Norder",
"Dir",
"Npix",
"Field_dual",
"ID_dual",
"RA_dual",
"DEC_dual",
"X_dual",
"Y_dual",
"A_dual",
"ELLIPTICITY_dual",
"ELONGATION_dual",
"FWHM_dual",
"KRON_RADIUS_dual",
"ISOarea_dual",
"MU_MAX_r_dual",
"s2n_DET_PStotal_dual",
"SEX_FLAGS_DET_dual",
"r_PStotal_dual",
"e_r_PStotal_dual",
"g_PStotal_dual",
"i_PStotal_dual",
"u_PStotal_dual",
"z_PStotal_dual",
"J0378_PStotal_dual",
"J0395_PStotal_dual",
"J0410_PStotal_dual",
"J0430_PStotal_dual",
"J0515_PStotal_dual",
"J0660_PStotal_dual",
"J0861_PStotal_dual",
"RA_psf",
"DEC_psf",
"r_psf_psf",
"e_r_psf_psf",
"g_psf_psf",
"e_g_psf_psf",
"i_psf_psf",
"e_i_psf_psf",
"u_psf_psf",
"e_u_psf_psf",
"z_psf_psf",
"e_z_psf_psf",
"J0378_psf_psf",
"e_J0378_psf_psf",
"J0395_psf_psf",
"e_J0395_psf_psf",
"J0410_psf_psf",
"e_J0410_psf_psf",
"J0430_psf_psf",
"e_J0430_psf_psf",
"J0515_psf_psf",
"e_J0515_psf_psf",
"J0660_psf_psf",
"e_J0660_psf_psf",
"J0861_psf_psf",
"e_J0861_psf_psf",
]

# %%
df_Ha_ = df_Ha[keep_columns]

# %%
df_Ha_.to_csv("../GUVcat_AISxSDSS_HSmaster-splusDr4-2arcsec-Halpha_final.csv", index=False)
